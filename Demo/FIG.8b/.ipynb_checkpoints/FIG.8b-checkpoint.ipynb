# %%
import scipy.integrate as sci
import cmath
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

import matplotlib


# plt.style.use('classic')
# plt.style.use('bmh')
print(plt.style.available)
plt.rc('font', family='Times New Roman', size=30)
plt.rc('axes', linewidth=2)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['mathtext.fontset'] = 'cm'

plt.rcParams['xtick.major.size'] = 5
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['xtick.minor.width'] = 2

plt.rcParams['ytick.major.size'] = 5
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['ytick.minor.width'] = 2

d=0.20285625840961555
au2cm=2.1947e5
# energy_list=[0.278284,0.278284]
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}




#设置横纵坐标的名称以及对应字体格式
font2 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 40,
}



font3 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 46
}
color_list=['#0000FF','#FF0000','#FFC000','#00CED1','#F20687','#454545','#454545']

au2cm =219474.63
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#Plot FIG.4b


# wrong for ZT

# %%
Nr = 2
Nc = 3

fig, axs = plt.subplots(Nr, Nc,figsize=(14.4,14),sharey=True,sharex=True)





e_ph_list=[]
e_ph_list.append(np.load('../data/2d_zt/2d_j_0lambda-1p1a/agg_s1_e_ph_correlation.npy'))
e_ph_list.append(np.load('../data/2d_zt/2d_j_0.2lambda-1p1a/agg_s1_e_ph_correlation.npy'))
e_ph_list.append(np.load('../data/2d_zt/2d_j_0.4lambda-1p1a/agg_s1_e_ph_correlation.npy'))
e_ph_list.append(np.load('../data/2d_zt/2d_j_0.6lambda-1p1a/agg_s1_e_ph_correlation.npy'))


lattice = 6
x=np.linspace(-20,20,20*2-1)


d0 = 25.04137327 *0.5
dx=0.5
dy=0.5
x = np.arange(-2.0, 2.5, dx)
y = np.arange(-2.0, 2.5, dy)

extent = np.min(x), np.max(x), np.min(y), np.max(y)
for inum  in range(len(e_ph_list)):
    sum_d_mt = np.zeros((lattice,lattice))
    for i in range(lattice**2):
        for j in range(lattice**2):
            if np.floor(j/lattice) >=  np.floor(i/lattice):
                icolumn=int(np.floor(j/lattice) - np.floor(i/lattice))
            else:
                icolumn=int(np.floor(j/lattice) - np.floor(i/lattice))+lattice
            if j%lattice  >= i%lattice:
                iline = j%lattice - i%lattice
            else:
                iline = j%lattice - i%lattice +lattice            
            sum_d_mt[icolumn,iline] = sum_d_mt[icolumn,iline] + e_ph_list[inum][1,i,j]

        
    x= 2
    y=2
    center= tuple([x,y])
    tuple_x = (np.arange(lattice) -x)% lattice 
    tuple_y = (np.arange(lattice) -y)% lattice 
    res_sum_d_mt = (sum_d_mt[tuple_x,:])[:,tuple_y]
    if inum >=1:
        
        
        #Wrong Wrong Wrong
        axs[0,inum-1].imshow(np.log(-1*res_sum_d_mt[0:-1,0:-1]/d0),cmap=cm.Spectral,vmin=-6,vmax=0,extent=extent)
        print(res_sum_d_mt[2,2]/d0)
        axs[0,inum-1].set_yticks([-2,-1,0,1,2])
        axs[0,inum-1].set_xticks([-2,-1,0,1,2])
        if inum == 1:
            axs[0,inum-1].set_ylabel('$r_y$' )

    
e_ph_list=[]
e_ph_list.append(np.load('../data/2d_rt/2d_j_0lambda-1p1a/agg_s1_e_ph_correlation.npy'))
e_ph_list.append(np.load('../data/2d_rt/2d_j_0.2lambda-1p1a/agg_s1_e_ph_correlation.npy'))
e_ph_list.append(np.load('../data/2d_rt/2d_j_0.4lambda-1p1a/agg_s1_e_ph_correlation.npy'))
e_ph_list.append(np.load('../data/2d_rt/2d_j_0.6lambda-1p1a/agg_s1_e_ph_correlation.npy'))



lattice = 6
x=np.linspace(-20,20,20*2-1)
d0 = 25.04137327*0.5
dx=0.5
dy=0.5
x = np.arange(-2.0, 2.5, dx)
y = np.arange(-2.0, 2.5, dy)

extent = np.min(x), np.max(x), np.min(y), np.max(y)
for inum  in range(len(e_ph_list)):
    sum_d_mt = np.zeros((lattice,lattice))
    for i in range(lattice**2):
        for j in range(lattice**2):
            if np.floor(j/lattice) >=  np.floor(i/lattice):
                icolumn=int(np.floor(j/lattice) - np.floor(i/lattice))
            else:
                icolumn=int(np.floor(j/lattice) - np.floor(i/lattice))+lattice
            if j%lattice  >= i%lattice:
                iline = j%lattice - i%lattice
            else:
                iline = j%lattice - i%lattice +lattice            
            sum_d_mt[icolumn,iline] = sum_d_mt[icolumn,iline] + e_ph_list[inum][1,i,j]

        
    x= 2
    y=2
    center= tuple([x,y])
    tuple_x = (np.arange(lattice) -x)% lattice 
    tuple_y = (np.arange(lattice) -y)% lattice 
    res_sum_d_mt = (sum_d_mt[tuple_x,:])[:,tuple_y]
    if inum >= 1:
        print((np.abs(res_sum_d_mt[0:-1,0:-1])/d0).shape)
        print(np.log(-1*res_sum_d_mt[2,2]/d0))
        image=axs[1,inum-1].imshow(np.log(-1*res_sum_d_mt[0:-1,0:-1]/d0),cmap=cm.
                                   Spectral,vmin=-6,vmax=0,extent=extent)
        print("max is {}, min is {}".format(np.log(-1*res_sum_d_mt[0:-1,0:-1]/d0).max(),np.log(-1*res_sum_d_mt[0:-1,0:-1]/d0).min()))  
        axs[1,inum-1].set_yticks([-2,-1,0,1,2])
        axs[1,inum-1].set_xticks([-2,-1,0,1,2])
        if inum == 1:
            axs[1,inum-1].set_ylabel('$r_y$' )
        axs[1,inum-1].set_xlabel('$r_x$ \n $|J|=$%.2f $\lambda$' % (inum*0.2))
    
print("max is {}, min is {}".format(np.log10(-1*res_sum_d_mt[0:-1,0:-1]/d0).max(),np.log10(-1*res_sum_d_mt[0:-1,0:-1]/d0).min()))    
fig.text(0.496,0.89,'ZT')
fig.text(0.496,0.6,'RT')
cba=fig.colorbar(image,ax=axs,orientation='vectical')
cba.ax.set_xlabel('$\mathrm{ln} (D(r_x,r_y)/g)$')
plt.savefig('FIG.8b.png',box_inches='tight')
plt.savefig('FIG.8b.pdf',box_inches='tight')
# Out:
# -0.7859398004275454
# -0.6354818987008058
# -0.5328121262422901
# (5, 5)
# -0.08211758324033568
# max is -0.08211758324033568, min is -9.628333703710483
# (5, 5)
# -0.27739645942910257
# max is -0.27739645942910257, min is -8.690355757530288
# (5, 5)
# -0.49115926698442913
# max is -0.49115926698442913, min is -7.3198316038698295
# max is -0.21330775938698357, min is -3.1789624740216964
# C:\Users\86133\AppData\Local\Continuum\anaconda3\envs\ephMPS\lib\site-packages\ipykernel_launcher.py:116: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# C:\Users\86133\AppData\Local\Continuum\anaconda3\envs\ephMPS\lib\site-packages\ipykernel_launcher.py:117: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
