# %%
from ephMPS.utils import constant

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2019-08-12 14:30:22,109[DEBUG] $HOME=/Users/jiang
# 2019-08-12 14:30:22,110[DEBUG] CONFIGDIR=/Users/jiang/.matplotlib
# 2019-08-12 14:30:22,111[DEBUG] matplotlib data path: /Users/jiang/anaconda/lib/python3.6/site-packages/matplotlib/mpl-data
# 2019-08-12 14:30:22,118[DEBUG] loaded rc file /Users/jiang/anaconda/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc
# 2019-08-12 14:30:22,126[DEBUG] matplotlib version 3.0.3
# 2019-08-12 14:30:22,127[DEBUG] interactive is False
# 2019-08-12 14:30:22,129[DEBUG] platform is darwin
# ...

# %%
a = np.load('spectra.npy').ravel()

# %%
b = np.linspace(0.05, 0.11, num=1200)

# %%
plt.plot(b,a)

# %%
plt.show()
# Out:
# 2019-08-12 14:30:23,638[DEBUG] update_title_pos
# 2019-08-12 14:30:23,665[DEBUG] findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/Users/jiang/anaconda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# 2019-08-12 14:30:23,733[DEBUG] update_title_pos
# 2019-08-12 14:30:23,768[DEBUG] update_title_pos
# 2019-08-12 14:30:23,796[DEBUG] update_title_pos
